# %%
import os

dataset_name = "hand_dataset01"
dataset_root = os.path.join("..", "dataset", dataset_name)

coords_file = os.path.join(dataset_root, "coords.txt") 
truth_file = os.path.join(dataset_root, "truth.txt")

# %%
import pandas as pd

# %%
truth = pd.read_csv(truth_file, )

# %%
truth.head()
# Out:
#    c2aea168-a955-4f01-866f-addf982284cf  2
# 0  f68ba371-747e-4458-a202-19c515016180  3
# 1  19010c2c-cb57-40b8-be17-629a884887c6  2
# 2  6fbbaec5-8020-4877-bb1f-8e66bc0ab9de  2
# 3  51dc24fd-74ab-4454-a80a-8dd6f18e32b6  2
# 4  1d94079c-8086-4061-a8d7-3d63b5b6d66c  3
